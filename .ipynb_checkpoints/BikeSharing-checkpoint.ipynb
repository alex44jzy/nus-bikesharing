# %%
# import libs
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from datetime import datetime
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
cwd = os.getcwd()
data_file_name = "/dataset/day.csv"
dataset = pd.read_csv(cwd + data_file_name)
dataset.shape #(731, 16)
# Out:
# (731, 16)

# %%
dataset[665:669]
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 665      666  2012-10-27       4   1    10        0        6           0
# 666      667  2012-10-28       4   1    10        0        0           0
# 667      668  2012-10-29       4   1    10        0        1           1
# 668      669  2012-10-30       4   1    10        0        2           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 665           2  0.530000  0.515133  0.720000   0.235692    2643        5209
# 666           2  0.477500  0.467771  0.694583   0.398008     998        3461
# 667           3  0.440000  0.439400  0.880000   0.358200       2          20
# 668           2  0.318182  0.309909  0.825455   0.213009      87        1009
#
#       cnt
# 665  7852
# 666  4459
# 667    22
# 668  1096

# %%
# convert string to datetime
dataset.dteday = dataset.dteday.apply(lambda x:pd.to_datetime(x))
dataset = dataset.drop(['instant'], axis = 1)
dataset = dataset.rename(columns={'registered': 'regist'})
dataset[dataset.dteday == '2012-10-29'].index
dataset = dataset.drop(dataset[dataset.dteday == '2012-10-29'].index)

# %%
# calculate the ahead n-7 to n-2 days average number
def calcAvgShift(dfCol, period, exclude):
    try:
        summary = dfCol.rolling(period).mean()
        if period is None:
            return dfCol
        if exclude is None:
            return summary
        mean = dfCol.shift(exclude).rolling(period, 1).mean()
        return mean.apply(lambda x: round(x, 3))
    except Exception as e:
        print("error:" + str(e))

# %%
def calcIncreaseRatio(pre, comp):
    inc = (comp - pre) / pre
    return round(inc, 3)

# %%
# dataset['cnt_lag2'] = dataset['cnt'].shift(2)
dataset['casual_lag2'] = dataset['casual'].shift(2)
dataset['regist_lag2'] = dataset['regist'].shift(2)
dataset['temp_inc'] = calcIncreaseRatio(dataset.temp.shift(1), dataset.temp)
dataset['temp_inc2day'] = calcIncreaseRatio(dataset.temp.shift(2), dataset.temp.shift(1))
# dataset['hum_inc2day'] = calcIncreaseRatio(dataset.hum.shift(2), dataset.hum.shift(1))
dataset['casual_avg_aheadWeek'] = calcAvgShift(dataset.casual, 7, 2)
dataset['regist_avg_aheadWeek'] = calcAvgShift(dataset.regist, 7, 2)
dataset['casual_avg_ahead3days'] = calcAvgShift(dataset.casual, 5, 2)
dataset['regist_avg_ahead3days'] = calcAvgShift(dataset.regist, 5, 2)
dataset['casual_avg_aheadMonth'] = calcAvgShift(dataset.casual, 31, 2)
dataset['regist_avg_aheadMonth'] = calcAvgShift(dataset.regist, 31, 2)
dataset['casual_median_LastWeek'] = dataset.casual.shift(2).rolling(7, 1).median()
dataset['regist_median_LastWeek'] = dataset.casual.shift(2).rolling(7, 1).median()
dataset['casual_max_LastWeek'] = dataset.casual.shift(2).rolling(7, 1).max()
dataset['regist_max_LastWeek'] = dataset.casual.shift(2).rolling(7, 1).max()
# dataset['casual_inc_ratio_monthly'] = calcIncreaseRatio(calcAvgShift(dataset.casual, 31, 2), dataset.casual_lag2)
# dataset['regist_inc_ratio_monthly'] = calcIncreaseRatio(calcAvgShift(dataset.regist, 31, 2), dataset.regist_lag2)
dataset['casual_inc_ratio_weekly'] = calcIncreaseRatio(calcAvgShift(dataset.casual, 7, 2), dataset.casual_lag2)
dataset['regist_inc_ratio_weekly'] = calcIncreaseRatio(calcAvgShift(dataset.regist, 7, 2), dataset.regist_lag2)
dataset['casual_lastWeekday'] = dataset.casual.shift(7)
dataset['regist_lastWeekday'] = dataset.regist.shift(7)
dataset['casual_inc_ratio'] = ((dataset['casual'] - dataset['casual_lag2']) / dataset['casual_lag2']).apply(lambda x:round(x, 3))
dataset['regist_inc_ratio'] = ((dataset['regist'] - dataset['regist_lag2']) / dataset['regist_lag2']).apply(lambda x:round(x, 3))
dataset.to_csv("./totalBikeSharing.csv", index=False)

# %%
# one hot encode dummy encode
dummy_season = pd.get_dummies(dataset.season, prefix="season")
dummy_weathersit = pd.get_dummies(dataset.weathersit, prefix="weathersit")
dataset = pd.concat([dataset, dummy_season, dummy_weathersit], axis = 1)

# %%
# drop columns and mark some columns
casual_cols = dataset.filter(like = 'casual').columns.values # filter the column name contain casual
regist_cols = dataset.filter(like = 'regist').columns.values
oneHotCols = dataset.filter(regex='holiday|workingday|weathersit_|season_').columns.values
exclude_dict = {'casual': regist_cols, 'regist': casual_cols}

# %%
# split train and test
target = 'regist'
target_col_name = target + '_inc_ratio'

train = dataset[dataset.dteday < datetime(2012, 1, 1)]
test = dataset[dataset.dteday > datetime(2011, 12, 31)]

train_Y_origin = train[target]
test_Y_origin = test[target]

train_Y = train[target_col_name]
test_Y = test[target_col_name]

drop_col = ['dteday', 'yr', 'mnth', 'weekday', 'season', 'weathersit', 'cnt', 'atemp', 'windspeed'
           ]
drop_col.extend([target_col_name, target])

drop_col.extend(list(exclude_dict[target]))

train_X = train.drop(drop_col, axis = 1)
test_X = test.drop(drop_col, axis = 1)
standCols = [i for i in train_X.columns.values if i not in oneHotCols]
standCols
# Out:
# ['temp',
#  'hum',
#  'regist_lag2',
#  'temp_inc',
#  'temp_inc2day',
#  'regist_avg_aheadWeek',
#  'regist_avg_ahead3days',
#  'regist_avg_aheadMonth',
#  'regist_max_LastWeek',
#  'regist_inc_ratio_monthly',
#  'regist_inc_ratio_weekly',
#  'regist_lastWeekday']

# %%
train_X = train_X[7:] # remove the begining 7 NaN
train_Y = train_Y[7:]

# %%
# standardization
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(train_X[standCols])
train_X.loc[:, standCols] = scaler.transform(train_X[standCols])
test_X.loc[:, standCols] = scaler.transform(test_X[standCols])

# %%
from xgboost.sklearn import XGBRegressor
from xgboost import plot_importance, plot_tree, to_graphviz

regr = XGBRegressor()
regr.fit(train_X, train_Y)

regr.feature_importances_
plot_importance(regr, max_num_features=10,  height=0.7,
                    title = 'Important features (XgBoost)',
                   grid = False, ylabel="", show_values=False)

# %%
regr.feature_importances_
# Out:
# array([0.03958692, 0.06024097, 0.12048193, 0.14802065, 0.07745267,
#        0.0757315 , 0.08261618, 0.05851979, 0.02581756, 0.02409638,
#        0.05163511, 0.07745267, 0.08605852, 0.01893288, 0.00860585,
#        0.00172117, 0.        , 0.00516351, 0.01376936, 0.        ,
#        0.02409638], dtype=float32)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from keras.layers import Dropout
from keras import regularizers

EPOCHS = 30
BATCH_SIZE = 5


model = Sequential()
model.add(Dense(train_X.shape[1], input_dim = train_X.shape[1], kernel_initializer='normal', activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(8, kernel_initializer='normal', activation='relu'))
model.add(Dense(1, kernel_initializer='normal'))
# Compile model
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(train_X, train_Y, epochs=EPOCHS, validation_data=(test_X, test_Y), batch_size=BATCH_SIZE, verbose = 2)
train_Y_prediction = model.predict(train_X)
test_Y_prediction = model.predict(test_X)
model.summary()
# Out:
# Train on 358 samples, validate on 365 samples
# Epoch 1/30
#  - 1s - loss: 0.3335 - val_loss: 0.3071
# Epoch 2/30
#  - 0s - loss: 0.2898 - val_loss: 0.2346
# Epoch 3/30
#  - 0s - loss: 0.1971 - val_loss: 0.1766
# Epoch 4/30
#  - 0s - loss: 0.1477 - val_loss: 0.1715
# Epoch 5/30
#  - 0s - loss: 0.1389 - val_loss: 0.1897
# Epoch 6/30
#  - 0s - loss: 0.1272 - val_loss: 0.2016
# Epoch 7/30
#  - 0s - loss: 0.1183 - val_loss: 0.1717
# Epoch 8/30
#  - 0s - loss: 0.1257 - val_loss: 0.2107
# Epoch 9/30
#  - 0s - loss: 0.1181 - val_loss: 0.1668
# Epoch 10/30
#  - 0s - loss: 0.1176 - val_loss: 0.2256
# Epoch 11/30
#  - 0s - loss: 0.1012 - val_loss: 0.1692
# Epoch 12/30
#  - 0s - loss: 0.0942 - val_loss: 0.1915
# Epoch 13/30
#  - 0s - loss: 0.1037 - val_loss: 0.1652
# Epoch 14/30
#  - 0s - loss: 0.0919 - val_loss: 0.1523
# Epoch 15/30
#  - 0s - loss: 0.1050 - val_loss: 0.1561
# Epoch 16/30
#  - 0s - loss: 0.0928 - val_loss: 0.1539
# Epoch 17/30
#  - 0s - loss: 0.0996 - val_loss: 0.1350
# Epoch 18/30
#  - 0s - loss: 0.0749 - val_loss: 0.1712
# Epoch 19/30
#  - 0s - loss: 0.0769 - val_loss: 0.1470
# Epoch 20/30
#  - 0s - loss: 0.0741 - val_loss: 0.1461
# Epoch 21/30
#  - 0s - loss: 0.0654 - val_loss: 0.1443
# Epoch 22/30
#  - 0s - loss: 0.0851 - val_loss: 0.1469
# Epoch 23/30
#  - 0s - loss: 0.0681 - val_loss: 0.1252
# Epoch 24/30
#  - 0s - loss: 0.0685 - val_loss: 0.1403
# Epoch 25/30
#  - 0s - loss: 0.0776 - val_loss: 0.1287
# Epoch 26/30
#  - 0s - loss: 0.0676 - val_loss: 0.1380
# Epoch 27/30
#  - 0s - loss: 0.0659 - val_loss: 0.1519
# Epoch 28/30
#  - 0s - loss: 0.0692 - val_loss: 0.1324
# Epoch 29/30
#  - 0s - loss: 0.0628 - val_loss: 0.1420
# Epoch 30/30
#  - 0s - loss: 0.0569 - val_loss: 0.1224
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_73 (Dense)             (None, 21)                462
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 21)                0
# _________________________________________________________________
# dense_74 (Dense)             (None, 8)                 176
# _________________________________________________________________
# dense_75 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 647
# Trainable params: 647
# Non-trainable params: 0
# _________________________________________________________________

# %%
test['pred_ratio'] = test_Y_prediction.flatten()
test['prediction_value'] = test.regist_lag2 * ( 1 + test.pred_ratio)
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
result_train = pd.DataFrame({'train_Y':train_Y, \
              'pred_train_Y':train_Y_prediction.flatten()
             })
time = [x + 1 for x in range(0, result_train.shape[0])]


# pd.DataFrame({'train_Y': train_Y,\
#               'pred_train_Y': train_Y_prediction.flatten()
#              })
plt.figure(figsize=(12,3))
plt.plot(time, result_train.train_Y, color='green', label='train')
plt.plot(time, result_train.pred_train_Y, color='red', label='train_prediction')
axes = plt.gca()
axes.set_ylim([-1,5])
plt.show()

# %%
# test_Y_prediction.flatten()



result = pd.DataFrame({'test_Y':test_Y, \
              'pred_test_Y':test_Y_prediction.flatten()
             })

time = [x + 1 for x in range(0, result.shape[0])]


# pd.DataFrame({'train_Y': train_Y,\
#               'pred_train_Y': train_Y_prediction.flatten()
#              })
plt.figure(figsize=(12,3))
plt.plot(time, result.test_Y, color='green', label='test')
plt.plot(time, result.pred_test_Y, color='red', label='test_prediction')
plt.plot(time, [0 for i in range(0, result.shape[0])], color = 'black')
axes = plt.gca()
axes.set_ylim([-1,5])
plt.show()

# %%
# test['prediction_value']
# test['regist']
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

plt.figure()
plt.scatter(test['prediction_value'], test['regist'])
plt.show()
mse_NN = mean_squared_error(test['prediction_value'], test['regist'])
mse_NN**(0.5)
# Out:
# 1064.1073717558809

# %%
revenuePerBike = 3
loanCostPerBike = 2
profit = pd.DataFrame({'test_regist_predict':test['prediction_value'], \
              'test_regist':test['regist']
             })
profit['revenue_daily'] = profit.apply(lambda x: revenuePerBike * min(x['test_regist'], x['test_regist_predict']), axis = 1)
profit['cost_daily'] = profit.apply(lambda x:x['test_regist_predict'] * loanCostPerBike, axis = 1)
profit['profit_daily'] = profit.revenue_daily - profit.cost_daily
profit['test_lag2'] = test.regist_lag2
profit['benchmark_profit'] = profit.apply(
    lambda x: (min(x['test_lag2'], x['test_regist']) * revenuePerBike - loanCostPerBike * x['test_lag2']),
    axis = 1
) 
totalProfit = profit.profit_daily.sum()
totalProfit

# profit.benchmark_profit.sum()
# Out:
# 1317148.2980816364

# %%
profit.test_regist.sum()
# Out:
# 1676791

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')

# %%
# standardization
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(train_X[standCols])
train_X.loc[:, standCols] = scaler.transform(train_X[standCols])
test_X.loc[:, standCols] = scaler.transform(test_X[standCols])
# Out:
# /usr/local/lib/python3.6/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
# baseline
from sklearn.metrics import mean_squared_error
lag2 = dataset[dataset.dteday > datetime(2011, 12, 31)]['regist_lag2']
currt = dataset[dataset.dteday > datetime(2011, 12, 31)]['registered']
mse = mean_squared_error(lag2, currt)
mse
plt.figure()
plt.scatter(dataset[dataset.dteday > datetime(2011, 12, 31)]['regist_lag2'], dataset[dataset.dteday > datetime(2011, 12, 31)]['registered'])
plt.show()

# %%
numerical_cols = ['temp', 'atemp', 'hum', 'windspeed','casual', 'registered', 'casual_lag2', 'regist_lag2',
       'avg_casual_aheadWeek', 'avg_regist_aheadWeek',
       'avg_casual_aheadMonth', 'avg_regist_aheadMonth',
       'lastWeekday_casual', 'lastWeekday_regist']

# %%
train = dataset[dataset.dteday < datetime(2012, 1, 1)]
test = dataset[dataset.dteday > datetime(2011, 12, 31)]
y_train_register = train.registered
y_test_register = test.registered

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(train[numerical_cols])
train[numerical_cols] = scaler.transform(train[numerical_cols])
test[numerical_cols] = scaler.transform(test[numerical_cols])
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
drop_col = ['dteday', 'yr', 'mnth', 'weekday', 'season', 'weathersit', 'cnt', 'registered']

# %%
train = train.drop(drop_col, axis = 1)
test = test.drop(drop_col, axis = 1)

# %%
train.columns.values
# Out:
# array(['holiday', 'workingday', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'casual_lag2', 'regist_lag2', 'avg_casual_aheadWeek',
#        'avg_regist_aheadWeek', 'avg_casual_aheadMonth',
#        'avg_regist_aheadMonth', 'lastWeekday_casual',
#        'lastWeekday_regist', 'season_1', 'season_2', 'season_3',
#        'season_4', 'weathersit_1', 'weathersit_2', 'weathersit_3'],
#       dtype=object)

# %%
# y_train_register = train.registered
# y_test_register = test.registered

# %%
clf = tree.DecisionTreeRegressor(max_depth=9)
clf = clf.fit(train_x, y_train_register[7:, ])
dt_test_predict = clf.predict(test_x)

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.scatter(dt_test_predict, y_test_register)
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression

# %%
regr = RandomForestRegressor(max_depth=20, random_state=0)
regr = regr.fit(train_x, y_train_register[7:, ])
rf_test_prediction = regr.predict(test_x)

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.scatter(rf_test_prediction, y_test_register)
plt.show()

# %%
mse = mean_squared_error(rf_test_prediction *1.5, y_test_register)
mse**(0.5)
# Out:
# 763.7595125868744

# %%
importances = regr.feature_importances_
importances
std = np.std([tree.feature_importances_ for tree in regr.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")

for f in range(test_x.shape[1]):
    print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))

# Plot the feature importances of the forest
plt.figure()
plt.title("Feature importances")
plt.bar(range(test_x.shape[1]), importances[indices],
       color="r", yerr=std[indices], align="center")
plt.xticks(range(test_x.shape[1]), indices)
plt.xlim([-1, test_x.shape[1]])
plt.show()
# Out:
# Feature ranking:
# 1. feature 7 (0.354694)
# 2. feature 8 (0.130683)
# 3. feature 10 (0.127063)
# 4. feature 1 (0.086496)
# 5. feature 3 (0.079284)
# 6. feature 4 (0.059502)
# 7. feature 16 (0.042433)
# 8. feature 5 (0.033951)
# 9. feature 2 (0.030039)
# 10. feature 6 (0.025759)
# 11. feature 9 (0.015617)
# 12. feature 15 (0.004990)
# 13. feature 14 (0.004963)
# 14. feature 13 (0.003287)
# 15. feature 0 (0.000628)
# 16. feature 11 (0.000321)
# 17. feature 12 (0.000290)

# %%
test_x.columns.values
# Out:
# array(['holiday', 'workingday', 'temp', 'atemp', 'hum', 'windspeed',
#        'regist_lag2', 'avg_regist_aheadWeek', 'avg_regist_aheadMonth',
#        'lastWeekday_regist', 'season_1', 'season_2', 'season_3',
#        'season_4', 'weathersit_1', 'weathersit_2', 'weathersit_3'],
#       dtype=object)

# %%
plt.figure()
plt.scatter(test, test_y)
plt.show()

# %%
test
# Out:
#      holiday  workingday      temp     atemp       hum  windspeed    casual  \
# 365        0           0 -0.645691 -0.569691  0.318955   0.007115 -0.003297
# 366        1           0 -1.161618 -1.306540 -1.776110   1.788584 -0.798660
# 367        0           1 -1.816354 -2.059594 -1.372535   2.255089 -1.077576
# 368        0           1 -2.042505 -2.101050 -1.552066  -0.089630 -1.066779
# 369        0           1 -1.199984 -1.150538 -0.814313  -0.798509 -0.985804
# 370        0           1 -0.836366 -0.780940 -0.693697  -0.307192 -0.685294
# 371        0           0 -0.521532 -0.479118 -0.763821  -0.218441  0.687696
# 372        0           0 -0.818630 -0.780993 -1.212643  -0.000982 -0.159851
# 373        0           1 -1.421697 -1.335371  0.380670  -1.201282 -1.046985
# 374        0           1 -0.971902 -0.909055  0.009417  -0.052678 -0.926421
# 375        0           1 -1.155637 -1.124193  1.362462  -0.782521 -1.072178
# 376        0           1 -0.579176 -0.531945  1.062315  -0.137995 -0.753673
# 377        0           1 -1.155637 -1.324119 -0.926521   2.416227 -0.924622
# 378        0           0 -1.656719 -1.720129 -1.263136  -0.057459 -0.638507
# 379        0           0 -1.727666 -1.848369 -1.521205   0.772717 -0.726681
# 380        1           0 -1.603507 -1.674860 -0.825536   0.514887 -0.847245
# 381        0           1 -0.629499 -0.637468  0.477750   2.040779 -1.009197
# 382        0           1 -1.000439 -1.169408 -1.358512   2.899770 -1.041587
# 383        0           1 -1.603507 -1.678595 -0.993844   0.369776 -1.003798
# 384        0           1 -1.457174 -1.493840 -1.313628   0.144232 -1.030790
# 385        0           0 -1.692195 -1.769197  1.253062   0.401959 -1.117164
# 386        0           0 -1.749839 -1.844635  1.017431   0.103912 -0.885034
# 387        0           1 -1.452741 -1.361787  1.791646  -1.048294 -0.976806
# 388        0           1 -0.792024 -0.728112  1.283916  -0.879097 -0.447764
# 389        0           1 -1.049213 -1.052491 -0.009245  -0.395775 -0.397380
# 390        0           1 -0.796457 -0.686632  0.837901  -1.531723 -0.798660
# 391        0           1 -0.353025 -0.332103  0.647155   1.957042 -0.753673
# 392        0           0 -0.933924 -0.863924 -0.685282   0.248906  0.156855
# 393        0           0 -1.111296 -1.184543 -2.247734   0.627503 -0.233628
# 394        0           1 -1.182243 -1.244870 -1.644635   0.313208 -1.010996
# ..       ...         ...       ...       ...       ...        ...       ...
# 701        0           0 -0.765418 -0.667762  1.199762  -0.871168  0.367392
# 702        0           1 -0.206692 -0.090625  0.823878  -1.410905 -0.239027
# 703        0           1 -0.082533 -0.011406  0.596662  -0.226591 -0.246225
# 704        0           1 -0.282078 -0.256642 -1.077997   1.715458 -0.642106
# 705        0           1 -1.253196 -1.271286 -0.918105  -0.218493 -0.625911
# 706        0           1 -0.907318 -0.890340  0.801439  -0.790567 -0.609716
# 707        0           0 -0.583609 -0.486713  1.791646  -1.169163  0.837052
# 708        0           0 -0.570306 -0.482900  1.752376  -0.435887 -0.444166
# 709        0           1 -0.295381 -0.211451  1.884215  -0.016970 -0.645705
# 710        0           1 -0.734380 -0.792316 -0.326222   1.352889 -0.730280
# 711        0           1 -1.031478 -1.037451 -0.718944  -0.371598 -0.679895
# 712        0           1 -1.040348 -1.056273 -1.072389  -0.226591 -0.472957
# 713        0           1 -1.115728 -1.056249 -0.014853  -0.782417 -0.465759
# 714        0           0 -0.889578 -0.792197  0.035640  -1.104757  0.142459
# 715        0           0 -0.685600 -0.603648  1.303554  -1.177417 -0.269618
# 716        0           1 -0.521532 -0.415057  1.763592  -1.209596 -0.856242
# 717        0           1 -0.428411 -0.366013  0.142232   0.385919 -0.458561
# 718        0           1 -0.845236 -0.769616 -0.132668  -0.097507 -0.638507
# 719        0           1 -0.858539 -0.811115  0.153455  -0.766429 -0.672697
# 720        0           1 -0.876275 -1.010986 -0.595514   2.367965 -0.840047
# 721        0           0 -1.199984 -1.403285 -1.372535   2.795044 -0.868839
# 722        0           0 -1.306408 -1.263715 -0.873221  -0.758396 -0.503548
# 723        0           1 -1.383720 -1.267127  0.984133  -1.482040 -0.924622
# 724        1           0 -1.064448 -1.054618  0.603617  -0.296594 -0.445965
# 725        0           1 -1.319711 -1.497575  1.199762   1.618610 -1.221533
# 726        0           1 -1.262061 -1.459877  0.052470   2.053774 -0.793261
# 727        0           1 -1.266499 -1.290156 -0.371106  -0.468330 -0.078875
# 728        0           0 -1.266499 -1.365719  0.725700  -0.871116 -0.951614
# 729        0           0 -1.253196 -1.429654 -1.089220   2.061820 -0.582724
# 730        0           1 -1.466044 -1.478729 -0.455260  -0.476428 -0.447764
#
#      registered  casual_lag2  regist_lag2      ...       \
# 365   -1.099850    -0.348608    -0.234642      ...
# 366   -1.005187    -0.036362    -0.890386      ...
# 367   -0.584458     0.001323    -1.092447      ...
# 368   -0.463977    -0.791855    -0.998088      ...
# 369    0.357400    -1.070006    -0.578717      ...
# 370    0.987537    -1.059239    -0.458625      ...
# 371    0.662428    -0.978486     0.360102      ...
# 372    0.064803    -0.678800     0.988206      ...
# 373   -0.466845     0.690420     0.664146      ...
# 374    0.637567    -0.154800     0.068449      ...
# 375   -0.643742    -1.039499    -0.461484      ...
# 376    1.022916    -0.919266     0.639365      ...
# 377    0.269430    -1.064623    -0.637810      ...
# 378   -0.572027    -0.746992     1.023471      ...
# 379   -0.699202    -0.917472     0.272416      ...
# 380   -0.647567    -0.632143    -0.566327      ...
# 381    0.047591    -0.720074    -0.693091      ...
# 382    0.486487    -0.840307    -0.641623      ...
# 383    0.386086    -1.001814     0.051293      ...
# 384    0.277079    -1.034116     0.488773      ...
# 385   -1.457470    -0.996431     0.388696      ...
# 386   -0.934428    -1.023349     0.280040      ...
# 387   -0.450590    -1.109486    -1.448912      ...
# 388    1.091763    -0.877992    -0.927558      ...
# 389    0.999011    -0.969513    -0.445281      ...
# 390    1.025785    -0.441924     1.092095      ...
# 391    0.409991    -0.391677     0.999643      ...
# 392    0.468320    -0.791855     1.026330      ...
# 393   -0.070022    -0.746992     0.412524      ...
# 394    0.707370     0.161036     0.470664      ...
# ..          ...          ...          ...      ...
# 701    0.955026    -0.580102     2.432177      ...
# 702    2.792845     0.476872     1.416155      ...
# 703    3.152377     0.370995     0.955800      ...
# 704    2.524152    -0.233759     2.787689      ...
# 705    2.177051    -0.240937     3.146061      ...
# 706    1.817520    -0.635732     2.519863      ...
# 707    1.597593    -0.619581     2.173882      ...
# 708    0.027511    -0.603431     1.815511      ...
# 709    1.991548     0.839365     1.596294      ...
# 710    2.352992    -0.438335     0.031277      ...
# 711    2.152190    -0.639321     1.988978      ...
# 712    2.245898    -0.723663     2.349256      ...
# 713    2.317613    -0.673417     2.149101      ...
# 714    1.455119    -0.467047     2.242507      ...
# 715    0.468320    -0.459869     2.313990      ...
# 716    1.544046     0.146680     1.454280      ...
# 717    2.262153    -0.264266     0.470664      ...
# 718    2.080475    -0.849280     1.542919      ...
# 719    1.009530    -0.452691     2.258710      ...
# 720    0.615575    -0.632143     2.077618      ...
# 721   -1.161047    -0.666239     1.010127      ...
# 722   -1.318821    -0.833129     0.617444      ...
# 723   -1.924096    -0.861842    -1.153446      ...
# 724   -2.089519    -0.497554    -1.310710      ...
# 725   -2.224343    -0.917472    -1.914033      ...
# 726   -0.852194    -0.440129    -2.078922      ...
# 727   -0.293773    -1.213568    -2.213311      ...
# 728   -1.507192    -0.786472    -0.845590      ...
# 729   -1.268142    -0.074047    -0.288970      ...
# 730   -0.447721    -0.944390    -1.498474      ...
#
#      avg_regist_aheadMonth  lastWeekday_casual  lastWeekday_regist  season_1  \
# 365              -0.123076           -0.681493           -2.187347         1
# 366              -0.181330           -0.454127           -1.772728         1
# 367              -0.251634           -1.039549           -1.609163         1
# 368              -0.322954           -0.767426           -0.669614         1
# 369              -0.350574           -0.769217           -0.553597         1
# 370              -0.371553           -0.344920           -0.231221         1
# 371              -0.387741           -0.033410           -0.885482         1
# 372              -0.339722            0.004186           -1.087086         1
# 373              -0.238241           -0.787119           -0.992941         1
# 374              -0.250799           -1.064613           -0.574518         1
# 375              -0.290324           -1.053872           -0.454697         1
# 376              -0.263575           -0.973309            0.362178         1
# 377              -0.273774           -0.674332            0.988861         1
# 378              -0.249782            0.691654            0.665534         1
# 379              -0.261687           -0.151569            0.071184         1
# 380              -0.312573           -1.034178           -0.457550         1
# 381              -0.367052           -0.914230            0.640809         1
# 382              -0.414890           -1.059242           -0.633478         1
# 383              -0.402404           -0.742362            1.024046         1
# 384              -0.364076           -0.912439            0.274689         1
# 385              -0.363387           -0.627784           -0.562156         1
# 386              -0.381026           -0.715508           -0.688633         1
# 387              -0.428900           -0.835457           -0.637282         1
# 388              -0.467373           -0.996583            0.054067         1
# 389              -0.458625           -1.028808            0.490557         1
# 390              -0.348143           -0.991212            0.390707         1
# 391              -0.226481           -1.018066            0.282297         1
# 392              -0.119628           -1.104000           -1.442745         1
# 393              -0.042391           -0.873053           -0.922570         1
# 394               0.001199           -0.964357           -0.441384         1
# ..                     ...                 ...                 ...       ...
# 701               1.921145           -0.670751           -0.604949         0
# 702               1.888226           -0.620623            1.900831         0
# 703               1.824237           -1.003744            1.031654         0
# 704               1.840570           -0.869472            2.197531         0
# 705               1.911200           -0.788910            2.214648         0
# 706               1.965353           -0.575866            2.429565         0
# 707               1.970942            0.478611            1.415842         0
# 708               1.950581            0.372984            0.956528         0
# 709               1.940418           -0.230341            2.784274         0
# 710               1.861004           -0.237503            3.141835         0
# 711               1.844962           -0.631365            2.517054         0
# 712               1.873018           -0.615252            2.171855         0
# 713               1.889242           -0.599140            1.814294         0
# 714               1.886883            0.840248            1.595573         0
# 715               1.938240           -0.434434            0.034096         0
# 716               1.907680           -0.634945            1.987369         0
# 717               1.839554           -0.719089            2.346832         0
# 718               1.809029           -0.668961            2.147130         0
# 719               1.838356           -0.463078            2.240324         0
# 720               1.881438           -0.455917            2.311646         1
# 721               1.836577            0.149199            1.453880         1
# 722               1.774948           -0.260776            0.472489         1
# 723               1.666534           -0.844408            1.542319         1
# 724               1.663231           -0.448756            2.256491         1
# 725               1.606574           -0.627784            2.075808         1
# 726               1.564036           -0.661800            1.010733         1
# 727               1.502951           -0.828296            0.618937         1
# 728               1.398312           -0.856940           -1.147947         1
# 729               1.348043           -0.493513           -1.304856         1
# 730               1.207218           -0.912439           -1.906813         1
#
#      season_2  season_3  season_4  weathersit_1  weathersit_2  weathersit_3
# 365         0         0         0             1             0             0
# 366         0         0         0             1             0             0
# 367         0         0         0             1             0             0
# 368         0         0         0             0             1             0
# 369         0         0         0             1             0             0
# 370         0         0         0             1             0             0
# 371         0         0         0             1             0             0
# 372         0         0         0             1             0             0
# 373         0         0         0             0             1             0
# 374         0         0         0             1             0             0
# 375         0         0         0             0             1             0
# 376         0         0         0             0             1             0
# 377         0         0         0             1             0             0
# 378         0         0         0             1             0             0
# 379         0         0         0             1             0             0
# 380         0         0         0             1             0             0
# 381         0         0         0             0             1             0
# 382         0         0         0             1             0             0
# 383         0         0         0             1             0             0
# 384         0         0         0             0             1             0
# 385         0         0         0             0             1             0
# 386         0         0         0             0             1             0
# 387         0         0         0             0             1             0
# 388         0         0         0             1             0             0
# 389         0         0         0             1             0             0
# 390         0         0         0             0             1             0
# 391         0         0         0             0             1             0
# 392         0         0         0             1             0             0
# 393         0         0         0             1             0             0
# 394         0         0         0             1             0             0
# ..        ...       ...       ...           ...           ...           ...
# 701         0         0         1             0             1             0
# 702         0         0         1             1             0             0
# 703         0         0         1             1             0             0
# 704         0         0         1             1             0             0
# 705         0         0         1             1             0             0
# 706         0         0         1             0             1             0
# 707         0         0         1             0             1             0
# 708         0         0         1             0             1             0
# 709         0         0         1             0             1             0
# 710         0         0         1             0             1             0
# 711         0         0         1             0             1             0
# 712         0         0         1             1             0             0
# 713         0         0         1             1             0             0
# 714         0         0         1             1             0             0
# 715         0         0         1             0             1             0
# 716         0         0         1             0             1             0
# 717         0         0         1             1             0             0
# 718         0         0         1             1             0             0
# 719         0         0         1             0             1             0
# 720         0         0         0             0             1             0
# 721         0         0         0             1             0             0
# 722         0         0         0             1             0             0
# 723         0         0         0             0             1             0
# 724         0         0         0             0             1             0
# 725         0         0         0             0             0             1
# 726         0         0         0             0             1             0
# 727         0         0         0             0             1             0
# 728         0         0         0             0             1             0
# 729         0         0         0             1             0             0
# 730         0         0         0             0             1             0
#
# [366 rows x 23 columns]
